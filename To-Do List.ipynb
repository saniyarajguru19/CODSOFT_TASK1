# %%
import tkinter as tk
from tkinter import messagebox

class ToDoListApp:
    def __init__(self, root):
        self.root = root
        self.root.title("To-Do List")
        
        self.tasks = []

        # Create task entry and buttons
        self.task_entry = tk.Entry(root, width=50)
        self.task_entry.grid(row=0, column=0, padx=10, pady=10)

        self.add_button = tk.Button(root, text="Add Task", command=self.add_task)
        self.add_button.grid(row=0, column=1, padx=10, pady=10)

        self.view_button = tk.Button(root, text="View Tasks", command=self.view_tasks)
        self.view_button.grid(row=1, column=0, columnspan=2, padx=10, pady=10)

        self.update_button = tk.Button(root, text="Update Task", command=self.update_task)
        self.update_button.grid(row=2, column=0, padx=10, pady=10)

        self.delete_button = tk.Button(root, text="Delete Task", command=self.delete_task)
        self.delete_button.grid(row=2, column=1, padx=10, pady=10)

        # Create task listbox
        self.task_listbox = tk.Listbox(root, width=60)
        self.task_listbox.grid(row=3, column=0, columnspan=2, padx=10, pady=10)

    def add_task(self):
        task = self.task_entry.get()
        if task:
            self.tasks.append(task)
            self.task_listbox.insert(tk.END, task)
            self.task_entry.delete(0, tk.END)
            messagebox.showinfo("Success", "Task added successfully!")
        else:
            messagebox.showerror("Error", "Task cannot be empty!")

    def view_tasks(self):
        if self.tasks:
            messagebox.showinfo("Your To-Do List", "\n".join(self.tasks))
        else:
            messagebox.showinfo("Your To-Do List", "Your To-Do List is empty.")

    def update_task(self):
        selected_index = self.task_listbox.curselection()
        if selected_index:
            index = selected_index[0]
            new_task = self.task_entry.get()
            if new_task:
                self.tasks[index] = new_task
                self.task_listbox.delete(index)
                self.task_listbox.insert(index, new_task)
                self.task_entry.delete(0, tk.END)
                messagebox.showinfo("Success", "Task updated successfully!")
            else:
                messagebox.showerror("Error", "Task cannot be empty!")
        else:
            messagebox.showerror("Error", "Please select a task to update!")

    def delete_task(self):
        selected_index = self.task_listbox.curselection()
        if selected_index:
            index = selected_index[0]
            del self.tasks[index]
            self.task_listbox.delete(index)
            messagebox.showinfo("Success", "Task deleted successfully!")
        else:
            messagebox.showerror("Error", "Please select a task to delete!")


def main():
    root = tk.Tk()
    app = ToDoListApp(root)
    root.mainloop()


if __name__ == "__main__":
    main()
# Out:
# 2024-05-21 17:08:18.858 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0f2860>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:08:51.777 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4ba0ae50>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:09:14.102 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47e99490>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:09:15.210 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0cbf70>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:09:40.412 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a1590c0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:09:41.915 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a15f870>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:07.015 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0e8c90>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:08.988 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0e6340>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:24.172 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0f2060>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:25.505 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0e6640>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:30.625 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4bb06cc0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:36.843 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a162300>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:42.962 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47e99490>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:47.597 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47bffcf0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:10:54.650 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0ef110>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:11:25.000 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0cbf70>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:11:27.653 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47bf85f0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:11:44.723 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0cbf70>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:14.919 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47eb52c0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:18.158 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0e7c10>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:23.953 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47ed8fd0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:26.535 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0cbf70>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:28.720 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a1691b0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:30.072 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47bf1530>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:34.138 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a15de00>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:37.455 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47eccfe0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:38.805 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a15fd40>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:40.922 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a163c10>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:53.635 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a1629c0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:12:56.085 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a0cbf70>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:13:12.328 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a169370>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:13:13.593 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47bf4520>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:13:38.986 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a163190>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:13:52.985 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a15ef10>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:14:45.280 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab4a164ea0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2024-05-21 17:15:03.375 python[1202:16581] Warning: Expected min height of view: (<NSButton: 0x7fab47bf5750>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
